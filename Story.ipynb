# %% [markdown]
# # Comparison of youth mortality over the past decade by season.

# %% [markdown]
# CBS provides data for the followoing specific age groups:
#
# `'0-19', '20-24', '25-29', '30-34', '35-39', '40-44', '45-49', '50-54',
# '55-59', '60-64', '65-69', '70-74', '75-79', '80-84', '85-89'`
#
# The data on deaths available since `2010 year`

# %%
from mortality_israel import MortalityIsrael

# %%
AGE_START = 20
AGE_END = 34

# %%
# Create table date | number of deaths for the specified age range
obj = MortalityIsrael(age_start=AGE_START, age_end=AGE_END)
df_population = obj.get_population_year()
df_date_death = obj.get_date_death_by_age()

# %%
# Plot number of deaths normalized by the age specified population over years

# %%
fig, ax = obj.plot_death_in_period_over_years('-01-01', '-02-28', 2012, 2022)

# %%
fig, ax = obj.plot_death_in_period_over_years('-02-01', '-03-31', 2010, 2022)

# %% [markdown]
# ### [2021 Meron crowd crush](https://en.wikipedia.org/wiki/2021_Meron_crowd_crush)
# <br>
# The deadliest civil disaster in Israel's history.
# <br>
# 30 April 2021

# %%
fig, ax = obj.plot_death_in_period_over_years('-03-01', '-04-30', 2010, 2022)

# %% [markdown]
# ### 2021 Misterious silent disaster

# %% [markdown]
# Let's exclude the Meron crowd crush in 30 April 2021

# %%
fig, ax = obj.plot_death_in_period_over_years('-03-01', '-04-29', 2010, 2022)

# %%
fig, ax = obj.plot_death_in_period_over_years('-04-01', '-05-31', 2010, 2022)

# %%
fig, ax = obj.plot_death_in_period_over_years('-05-01', '-06-30', 2010, 2022)

# %% [markdown]
# ### [2014 Gaza War](https://en.wikipedia.org/wiki/2014_Gaza_War)
#
# 8 July – 26 August 2014

# %%
fig, ax = obj.plot_death_in_period_over_years('-06-01', '-07-31', 2010, 2022)

# %%
fig, ax = obj.plot_death_in_period_over_years('-07-01', '-08-31', 2010, 2022)

# %%
fig, ax = obj.plot_death_in_period_over_years('-08-01', '-09-30', 2010, 2022)

# %%
fig, ax = obj.plot_death_in_period_over_years('-09-01', '-10-31', 2010, 2021)

# %%
fig, ax = obj.plot_death_in_period_over_years('-10-01', '-11-30', 2010, 2021)

# %% [markdown]
# ### [2010 Mount Carmel forest fire](https://en.wikipedia.org/wiki/2010_Mount_Carmel_forest_fire)
# <br>
# A forest fire began on Mount Carmel which would kill forty and burn nearly twenty square miles over the next three days.
# <br>
# 2 December – 5 December 2010

# %%
fig, ax = obj.plot_death_in_period_over_years('-11-01', '-12-31', 2010, 2021)
